# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.cm as cm
import numpy as np
from wordcloud import WordCloud

# %%
job_summary=pd.read_csv("/Users/ameymanagute/Desktop/A Spring 2025/A_DIC/CSE587/CSE587Project/dataset/job_summary.csv")

# %%
job_summary
# Out:
#                                                   job_link  \
# 0        https://www.linkedin.com/jobs/view/restaurant-...
# 1        https://www.linkedin.com/jobs/view/med-surg-re...
# 2        https://www.linkedin.com/jobs/view/registered-...
# 3        https://uk.linkedin.com/jobs/view/commercial-a...
# 4        https://www.linkedin.com/jobs/view/store-manag...
# ...                                                    ...
# 1297327  https://www.linkedin.com/jobs/view/roofing-sup...
# 1297328  https://www.linkedin.com/jobs/view/service-cen...
# 1297329  https://www.linkedin.com/jobs/view/flight-qual...
# 1297330  https://www.linkedin.com/jobs/view/global-sour...
# 1297331  https://www.linkedin.com/jobs/view/research-as...
#
#                                                job_summary
# 0        Rock N Roll Sushi is hiring a Restaurant Manag...
# 1        Schedule\n: PRN is required minimum 12 hours p...
# 2        Description\nIntroduction\nAre you looking for...
# ...

# %%
job_skills=pd.read_csv("/Users/ameymanagute/Desktop/A Spring 2025/A_DIC/CSE587/CSE587Project/dataset/job_skills.csv")

# %%
job_skills
# Out:
#                                                   job_link  \
# 0        https://www.linkedin.com/jobs/view/housekeeper...
# 1        https://www.linkedin.com/jobs/view/assistant-g...
# 2        https://www.linkedin.com/jobs/view/school-base...
# 3        https://www.linkedin.com/jobs/view/electrical-...
# 4        https://www.linkedin.com/jobs/view/electrical-...
# ...                                                    ...
# 1296376  https://www.linkedin.com/jobs/view/community-a...
# 1296377  https://www.linkedin.com/jobs/view/sr-it-analy...
# 1296378  https://www.linkedin.com/jobs/view/operations-...
# 1296379  https://www.linkedin.com/jobs/view/float-patie...
# 1296380  https://www.linkedin.com/jobs/view/conductor-e...
#
#                                                 job_skills
# 0        Building Custodial Services, Cleaning, Janitor...
# 1        Customer service, Restaurant management, Food ...
# 2        Applied Behavior Analysis (ABA), Data analysis...
# ...

# %%
job_postings=pd.read_csv("/Users/ameymanagute/Desktop/A Spring 2025/A_DIC/CSE587/CSE587Project/dataset/linkedin_job_postings.csv")

# %%
job_postings
# Out:
#                                                   job_link  \
# 0        https://www.linkedin.com/jobs/view/account-exe...
# 1        https://www.linkedin.com/jobs/view/registered-...
# 2        https://www.linkedin.com/jobs/view/restaurant-...
# 3        https://www.linkedin.com/jobs/view/independent...
# 4        https://www.linkedin.com/jobs/view/group-unit-...
# ...                                                    ...
# 1348449  https://www.linkedin.com/jobs/view/registered-...
# 1348450  https://www.linkedin.com/jobs/view/constructio...
# 1348451  https://www.linkedin.com/jobs/view/executive-c...
# 1348452  https://www.linkedin.com/jobs/view/rn-register...
# 1348453  https://www.linkedin.com/jobs/view/on-demand-g...
#
#                    last_processed_time got_summary got_ner is_being_worked  \
# 0         2024-01-21 07:12:29.00256+00           t       t               f
# 1         2024-01-21 07:39:58.88137+00           t       t               f
# ...

# %% [markdown]
# ### Checking For Missing Values

# %%
job_summary.isnull().sum()
# Out:
# job_link       0
# job_summary    0
# dtype: int64

# %%
job_skills.isnull().sum()
# Out:
# job_link         0
# job_skills    2085
# dtype: int64

# %%
job_postings.isnull().sum()
# Out:
# job_link                0
# last_processed_time     0
# got_summary             0
# got_ner                 0
# is_being_worked         0
# job_title               0
# company                11
# job_location           19
# first_seen              0
# search_city             0
# search_country          0
# search_position         0
# job_level               0
# job_type                0
# dtype: int64

# %% [markdown]
# ### Checking Duplicates

# %%
job_summary[job_summary.duplicated()]
# Out:
# Empty DataFrame
# Columns: [job_link, job_summary]
# Index: []

# %%
job_skills[job_skills.duplicated()]
# Out:
# Empty DataFrame
# Columns: [job_link, job_skills]
# Index: []

# %%
job_postings[job_postings.duplicated()]
# Out:
# Empty DataFrame
# Columns: [job_link, last_processed_time, got_summary, got_ner, is_being_worked, job_title, company, job_location, first_seen, search_city, search_country, search_position, job_level, job_type]
# Index: []

# %%
job_postings.describe()
# Out:
#                                                  job_link  \
# count                                             1348454
# unique                                            1348454
# top     https://www.linkedin.com/jobs/view/account-exe...
# freq                                                    1
#
#                   last_processed_time got_summary  got_ner is_being_worked  \
# count                         1348454     1348454  1348454         1348454
# unique                         722748           2        2               2
# top     2024-01-19 09:45:09.215838+00           t        t               f
# freq                           625540     1297877  1296401         1346978
#
#                       job_title          company  job_location  first_seen  \
# count                   1348454          1348443       1348435     1348454
# unique                   584544            90605         29153           6
# ...

# %%
job_postings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1348454 entries, 0 to 1348453
# Data columns (total 14 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   job_link             1348454 non-null  object
#  1   last_processed_time  1348454 non-null  object
#  2   got_summary          1348454 non-null  object
#  3   got_ner              1348454 non-null  object
#  4   is_being_worked      1348454 non-null  object
#  5   job_title            1348454 non-null  object
#  6   company              1348443 non-null  object
#  7   job_location         1348435 non-null  object
#  8   first_seen           1348454 non-null  object
#  9   search_city          1348454 non-null  object
#  10  search_country       1348454 non-null  object
#  11  search_position      1348454 non-null  object
#  12  job_level            1348454 non-null  object
#  13  job_type             1348454 non-null  object
# dtypes: object(14)
# ...

# %% [markdown]
# ### Data Cleaning

# %%
job_skills_cleaned=job_skills.dropna(subset=['job_skills'])

# %%
job_postings_cleaned=job_postings.dropna(subset=['company','job_location'])

# %% [markdown]
# ### Checking if there are still Missing Values left

# %%
job_skills_cleaned.isnull().sum()
# Out:
# job_link      0
# job_skills    0
# dtype: int64

# %%
job_postings_cleaned.isnull().sum()
# Out:
# job_link               0
# last_processed_time    0
# got_summary            0
# got_ner                0
# is_being_worked        0
# job_title              0
# company                0
# job_location           0
# first_seen             0
# search_city            0
# search_country         0
# search_position        0
# job_level              0
# job_type               0
# dtype: int64

# %% [markdown]
# ### Deleting Unnesccesary Columns

# %%
job_postings_cleaned=job_postings.drop(columns=['got_summary','got_ner','is_being_worked'])

# %%
job_postings_cleaned.columns
# Out:
# Index(['job_link', 'last_processed_time', 'job_title', 'company',
#        'job_location', 'first_seen', 'search_city', 'search_country',
#        'search_position', 'job_level', 'job_type'],
#       dtype='object')

# %% [markdown]
# ### Visualizations

# %%
top_jobs=job_postings_cleaned['job_title'].value_counts().head(20)
top_jobs
# Out:
# job_title
# LEAD SALES ASSOCIATE-FT                                7325
# Shift Manager                                          5818
# First Year Tax Professional                            5356
# Assistant Manager                                      5346
# Customer Service Representative                        5203
# LEAD SALES ASSOCIATE-PT                                4924
# Store Manager                                          4791
# CUSTOMER SERVICE REPRESENTATIVE                        4218
# Registered Nurse                                       4190
# Hourly Supervisor & Training                           2955
# Travel Allied Health Professional - CT Technologist    2933
# Host                                                   2871
# Account Executive                                      2631
# Senior Accountant                                      2548
# Restaurant Manager                                     2335
# ...

# %%
colors=cm.YlOrRd(np.linspace(1,0.2,len(top_jobs)))
top_jobs.plot(kind="bar",color=colors)
plt.title('Top 20 Job Titles')
plt.xlabel('Job Titles')
plt.ylabel('Number of Job Listings')
plt.xticks(rotation=45,ha='right')
plt.yticks()
plt.figure(figsize=(8,12))
plt.show()

# %%
top_companies=job_postings_cleaned['company'].value_counts().head(15)
top_companies

# %%
colors=cm.Blues(np.linspace(0.4,1,len(top_companies)))

# %%
top_companies.plot(kind='barh',color=colors,edgecolor='black')
plt.title('Top 15 Companies with Most Job Openings',fontsize=14)
plt.xlabel('Number of Job Listings',fontsize=14)
plt.ylabel('Company',fontsize=14)
plt.xticks(rotation=45,ha='right',fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
job_types=job_postings_cleaned['job_type'].value_counts()

# %%
colors=plt.cm.viridis(np.linspace(0.2, 0.8, len(job_types)))

# %%
job_types.plot(kind='bar',color=colors,edgecolor='black')
plt.title('Distribution of Job Types', fontsize=16)
plt.xlabel('Job Type', fontsize=14)
plt.ylabel('Number of Job Listings', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.ticklabel_format(style='plain', axis='y')
plt.tight_layout()
plt.show()

# %%
job_location_counts=job_postings_cleaned['job_location'].value_counts().head(10)

plt.figure(figsize=(8, 8))
plt.pie(job_location_counts, labels=job_location_counts.index, autopct='%1.2f%%',colors=plt.cm.Set3.colors)
plt.title('Top 10 Job Locations by Proportion', fontsize=16)
plt.tight_layout()
plt.show()

# %%
job_skills['job_skills'] = job_skills['job_skills'].astype(str)
job_skills_text=' '.join(job_skills['job_skills'])

# %%
wordcloud = WordCloud(
    width=800, 
    height=400, 
    background_color='white', 
    colormap='plasma',      
    max_words=100,        
    stopwords=None,           
).generate(job_skills_text)

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Job Skills', fontsize=16)
plt.tight_layout()
plt.show()

# %%
merged_data = pd.merge(job_postings_cleaned,job_skills_cleaned, on="job_link", how="left")
merged_data = pd.merge(merged_data, job_summary, on="job_link", how="left")

# Save the merged file
merged_data.to_csv("merged_jobs.csv", index=False)

# %%
merged_data
# Out:
#                                                   job_link  \
# 0        https://www.linkedin.com/jobs/view/account-exe...
# 1        https://www.linkedin.com/jobs/view/registered-...
# 2        https://www.linkedin.com/jobs/view/restaurant-...
# 3        https://www.linkedin.com/jobs/view/independent...
# 4        https://www.linkedin.com/jobs/view/group-unit-...
# ...                                                    ...
# 1348449  https://www.linkedin.com/jobs/view/registered-...
# 1348450  https://www.linkedin.com/jobs/view/constructio...
# 1348451  https://www.linkedin.com/jobs/view/executive-c...
# 1348452  https://www.linkedin.com/jobs/view/rn-register...
# 1348453  https://www.linkedin.com/jobs/view/on-demand-g...
#
#                    last_processed_time  \
# 0         2024-01-21 07:12:29.00256+00
# 1         2024-01-21 07:39:58.88137+00
# 2        2024-01-21 07:40:00.251126+00
# 3        2024-01-21 07:40:00.308133+00
# 4        2024-01-19 09:45:09.215838+00
# ...

# %%
merged_data.isnull().sum()
# Out:
# job_link                   0
# last_processed_time        0
# job_title                  0
# company                   11
# job_location              19
# first_seen                 0
# search_city                0
# search_country             0
# search_position            0
# job_level                  0
# job_type                   0
# job_skills             54158
# job_summary            51122
# dtype: int64

# %%
merged_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 merged
#
# NameError: name 'merged' is not defined

# %%
merged_data_cleaned=merged_data.dropna(subset=['company','job_location','job_skills','job_summary'])

# %%
merged_data_cleaned.isnull().sum()
# Out:
# job_link               0
# last_processed_time    0
# job_title              0
# company                0
# job_location           0
# first_seen             0
# search_city            0
# search_country         0
# search_position        0
# job_level              0
# job_type               0
# job_skills             0
# job_summary            0
# dtype: int64

# %%
merged_data_cleaned.to_csv("merged_data_jobs.csv", index=False)
